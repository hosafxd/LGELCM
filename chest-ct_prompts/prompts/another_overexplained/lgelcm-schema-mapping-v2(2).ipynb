# %% [markdown]
# # Installing Necessary Packages

# %%
# !pip -q install zai-sdk
# !pip -q install openai
# !pip -q install google-generativeai

# %% [markdown]
# # Import Packages

# %%
import os
import sys
import re
import time
import json
import random
import logging
import warnings
import requests

import numpy as np
import pandas as pd

from google import genai
from google.genai.types import GenerateContentConfig

from abc import ABC, abstractmethod

from zai import ZaiClient
from openai import OpenAI
from tqdm import tqdm
from kaggle_secrets import UserSecretsClient

pd.set_option('display.max_colwidth', None)
warnings.filterwarnings('ignore')

# %% [markdown]
# # Logging

# %%
logger = logging.getLogger()      # root logger
logger.setLevel(logging.WARNING)

if not logger.handlers:
    handler = logging.StreamHandler(sys.stdout)
    formatter = logging.Formatter("%(asctime)s %(levelname)s: %(message)s")
    handler.setFormatter(formatter)
    logger.addHandler(handler)

# %% [markdown]
# # System Prompt

# %%
PROMPT_TEMPLATE = """
You are an expert clinical NLP annotator extracting structured entities from CHEST CT radiology reports.

OUTPUT: Valid JSON array only. No markdown, no explanation, no comments.

SCHEMA:
[
  {
    "general_finding": "string or None",
    "specific_finding": "string or None",
    "finding_presence": "present | absent | uncertain | None",
    "location": [],
    "degree": [],
    "measurement": "string or None",
    "comparison": "stable | improved | worsened | None"
  }
]

═══════════════════════════════════════════════════
FIELD DEFINITIONS
═══════════════════════════════════════════════════

general_finding: The CLINICAL CATEGORY of what is being described.
  USE the clinical entity name, NOT the anatomical structure, NOT a generic category.

  CORRECT examples:
    "cardiomegaly", "pericardial effusion", "pulmonary embolus",
    "atherosclerotic plaque", "coronary artery calcification",
    "lymphadenopathy", "pleural effusion", "pneumothorax",
    "catheter", "endotracheal tube", "nasogastric tube",
    "hematoma", "fracture", "intramural hematoma",
    "lung parenchyma", "thyroid gland", "heart", "aorta",
    "thoracic aorta", "aortic arch", "pulmonary artery",
    "pulmonary arteries", "trachea", "central airways",
    "airways", "liver", "gallbladder", "bone",
    "lymph nodes", "pulmonary nodules", "pulmonary nodule",
    "soft tissue", "upper abdomen", "spine",
    "cholecystitis", "aortic pathology", "consolidation",
    "vertebral artery", "prior disease", "thyroid nodules",
    "great vessels", "upper abdominal organs"

  WRONG — never use generic categories like:
    ✗ "thyroid abnormality" → use "thyroid gland" or "thyroid nodules"
    ✗ "cardiac abnormality" → use "coronary artery calcification" or "heart"
    ✗ "vascular abnormality" → use "aorta", "pulmonary artery", etc.
    ✗ "parenchymal abnormality" → use "lung parenchyma" or "consolidation"
    ✗ "pleural abnormality" → use "pleural effusion" or "pneumothorax"
    ✗ "skeletal abnormality" → use "bone" or "fracture"
    ✗ "airway abnormality" → use "airways" or "trachea"
    ✗ "lymph node abnormality" → use "lymphadenopathy" or "lymph nodes"
    ✗ "liver lesion" → use "liver"
    ✗ "abdominal abnormality" → use "upper abdomen"

  For devices: general_finding = the device name itself:
    "catheter", "endotracheal tube", "nasogastric tube"

  For absent pathology: general_finding = the pathology name:
    "pericardial effusion" (not "pericardium" or "pericardial space")
    "pulmonary embolus" (not "pulmonary arteries")
    "cholecystitis" (not "gallbladder")
    "lymphadenopathy" (not "lymph nodes")
    "pneumothorax" (not "lungs")

specific_finding: The specific observation or descriptor.
  Use concise clinical terminology, not raw sentence fragments.
  CORRECT: "aberrant origin", "subcutaneous hematoma", "filling defects"
  WRONG: "left vertebral artery arising directly from the aorta" (too verbose)

location: Array of anatomical sites. ALWAYS populate when the report states a location.
  Include laterality. Include both insertion site AND tip position for devices.

degree: Array of qualifiers (mild, moderate, severe, small, focal, diffuse, patchy, etc.).
  Include descriptors like "suspicious", "significant", "bibasilar", "subcentimeter", "scattered".
  For unremarkable/normal findings, degree = ["unremarkable"] or ["normal"].
  Use empty array [] when no qualifiers apply. Never put "None" as a string inside the array.

measurement: Exact numeric value with units from text, or "None".

comparison: Only set if report compares to prior imaging. Otherwise "None".

═══════════════════════════════════════════════════
ENTITY GRANULARITY RULES
═══════════════════════════════════════════════════

RULE 1: ONE SENTENCE DESCRIBING ONE THING = ONE ENTITY
  Each distinct clinical observation gets its own entity.

RULE 2: SPLIT SEPARATE ANATOMICAL STRUCTURES
  "The aorta and great vessels are normal" = TWO entities:
    1. general_finding: "aorta", specific_finding: "aorta course and caliber"
    2. general_finding: "great vessels", specific_finding: "great vessels course and caliber"

  "Trachea and central bronchi are patent" = TWO entities:
    1. general_finding: "trachea", specific_finding: "patency"
    2. general_finding: "bronchi", specific_finding: "patency" (or "central airways"/"patency")

  "The trachea and central airways are patent" = TWO entities:
    1. general_finding: "trachea", specific_finding: "patency"
    2. general_finding: "central airways", specific_finding: "patency"

RULE 3: SPLIT SEPARATE CLINICAL FINDINGS ON SAME STRUCTURE
  "Heart is normal in size with a trace pericardial effusion" = TWO entities:
    1. general_finding: "heart", specific_finding: "heart size", degree: ["normal"]
    2. general_finding: "pericardial effusion", specific_finding: "pericardial effusion", degree: ["trace"]

  "Normal contour and caliber with moderate atherosclerotic plaque" = TWO entities:
    1. Contour/caliber entity
    2. Atherosclerotic plaque entity

  "Thyroid gland is heterogeneous with multiple small nodules in the right lobe" = TWO entities:
    1. general_finding: "thyroid gland", specific_finding: "heterogeneous thyroid", degree: ["heterogeneous"]
    2. general_finding: "thyroid nodules", specific_finding: "nodules", location: ["right thyroid lobe"], degree: ["multiple", "small"]

RULE 4: SEPARATE ABSENT PATHOLOGY FROM RELATED ABSENT PATHOLOGY
  "No surface irregularity to suggest intimal flap, dissection, or atheromatous ulcer"
  = TWO entities:
    1. general_finding: "thoracic aorta", specific_finding: "surface irregularity", finding_presence: "absent"
    2. general_finding: "aortic pathology", specific_finding: "intimal flap, dissection, or atheromatous ulcer", finding_presence: "absent"

RULE 5: MERGE — DEVICES
  Merge device insertion site + tip position into ONE entity with multi-location array.
  "Catheter in right IJ with tip in right atrium" → location: ["right internal jugular", "proximal right atrium"]

RULE 6: MERGE — GROUPED NEGATIVES (same clinical domain)
  "No focal consolidation, effusion or edema" → ONE entity:
    general_finding: "lung parenchyma", specific_finding: "consolidation, effusion, or edema", finding_presence: "absent"
  Include applicable qualifiers: degree: ["focal"]

RULE 7: MERGE — VERSUS / AND/OR STATEMENTS
  "consolidation versus atelectasis" or "atelectasis and/or scarring" → ONE entity:
    finding_presence: "uncertain"
    Keep wording: specific_finding: "consolidation versus atelectasis"

RULE 8: MERGE — COREFERENCES
  "Ground glass opacities are seen. These involve all lobes." → ONE entity

═══════════════════════════════════════════════════
IMPRESSION HANDLING
═══════════════════════════════════════════════════

- If IMPRESSION restates a FINDINGS entity with same information → extract ONLY ONCE (use FINDINGS version)
- If IMPRESSION adds new clinical significance → merge into the existing entity's degree
- Do NOT extract IMPRESSION-only summary statements that are not specific findings
  Example: "NO ACUTE VASCULAR INJURY" → Do NOT extract this as a separate entity (it's a summary)

═══════════════════════════════════════════════════
FINDING PRESENCE
═══════════════════════════════════════════════════

present: "is seen", "demonstrates", "present", "identified", "noted", "appreciated"
absent: "no", "without", "absent", "no evidence of", "negative for"
uncertain: "versus", "and/or", "possible", "suspicious for", "cannot exclude", "may represent"

═══════════════════════════════════════════════════
SPECIAL CASES
═══════════════════════════════════════════════════

NORMAL/UNREMARKABLE: Extract with finding_presence: "present", degree: ["unremarkable"] or ["normal"]
  "thyroid gland is unremarkable" → general_finding: "thyroid gland", degree: ["unremarkable"]
  "upper abdomen is unremarkable" → general_finding: "upper abdomen", degree: ["unremarkable"]

DEVICES: general_finding = device name. Location = [insertion site, tip position]. Measurement = distance if stated.
  "ET tube tip 2.5 cm above carina" → measurement: "2.5 cm above the carina"

SEQUELAE: Extract as separate entity.
  "calcified nodules, likely sequela of prior granulomatous process" → TWO entities:
    1. The calcified nodules
    2. general_finding: "prior disease", specific_finding: "sequela of prior granulomatous process"

LYMPH NODES:
  "no lymphadenopathy" → general_finding: "lymphadenopathy", finding_presence: "absent"
  "subcentimeter nodes present" → general_finding: "lymph nodes", finding_presence: "present", degree: ["subcentimeter"]
  Only extract lymphadenopathy as present if: "enlarged", "prominent", "pathologic"

LIMITED ASSESSMENT:
  "Lack of noncontrast images limits ability to assess for intramural hematoma"
  → general_finding: "intramural hematoma", finding_presence: "uncertain"

═══════════════════════════════════════════════════
COMMON ERRORS TO AVOID
═══════════════════════════════════════════════════

✗ Using generic categories ("vascular abnormality") instead of specific clinical terms
✗ Merging separate anatomical structures into one entity (trachea + bronchi, aorta + great vessels)
✗ Merging separate clinical findings on the same structure (heart size + pericardial effusion)
✗ Missing the heart size entity when it's stated
✗ Missing the pericardial effusion entity when it's stated (even if absent)
✗ Extracting IMPRESSION-only summary lines as new entities
✗ Leaving location empty when the report specifies a location
✗ Putting "None" as a string inside degree array (use empty [] instead)
✗ Missing qualifiers like "significant", "scattered", "bibasilar" in degree
✗ Using raw sentence fragments as specific_finding instead of concise terms

═══════════════════════════════════════════════════

NOW EXTRACT FROM THIS REPORT:

<<<REPORT_TEXT>>>

Output ONLY the JSON array.



"""

# %% [markdown]
# # API Keys

# %%
user_secrets = UserSecretsClient()

API_KEYS = {
    "gemini": user_secrets.get_secret("gemini_api_key_0"),
    "gemma": user_secrets.get_secret("gemini_api_key_0"),
    #"glm": user_secrets.get_secret("glm_api_key"),
    #"deepseek": user_secrets.get_secret("deepseek_api_key"),
}

# %% [markdown]
# # LLM Classes

# %%
class AIBaseModel(ABC):
    def __init__(self, api_key: str, model_name: str):
        self.api_key = api_key
        self.model_name = model_name
    
    @abstractmethod
    def invoke(self, prompt: str, **kwargs):
        raise NotImplementedError

# %%
class GeminiModel(AIBaseModel):
    def __init__(self, api_key: str, model_name: str = "gemini-2.5-flash"):
        self.model_name = model_name
        self.client = genai.Client(api_key=api_key)
        self.sleep_time = self._get_time_to_sleep()
        
    def _get_time_to_sleep(self):
        requests_per_minute = 15  # default
        
        if self.model_name == "gemini-2.5-flash":
            requests_per_minute = 5
        elif self.model_name == "gemini-3-flash-preview":
            requests_per_minute = 5
        elif self.model_name == "gemini-2.5-flash-lite":
            requests_per_minute = 10
        elif self.model_name == "gemini-1.5-flash":
            requests_per_minute = 15
        elif "gemma" in self.model_name:
            requests_per_minute = 30
            
        return 60 / requests_per_minute
    
    def invoke(
        self, 
        prompt: str,
        system_prompt: str | None = None,
        temperature: float = 0, 
        top_p: float = 1, 
        max_tokens: int = 8192,
    ):
        try:
            response = self.client.models.generate_content(
                model=self.model_name,
                contents=prompt,
                config=GenerateContentConfig(
                    system_instruction=None,
                    temperature=temperature,
                    top_p=top_p,
                    max_output_tokens=max_tokens,
                ),
            )

            if hasattr(response, "candidates"):
                texts = []
                for c in response.candidates:
                    for p in getattr(c.content, "parts", []):
                        if getattr(p, "text", None):
                            texts.append(p.text)
                return "\n".join(texts) if texts else None
            return None
        except Exception as e:
            logger.error(f"Gemini API error: {e}")
        return None

# %%
class GLMModel(AIBaseModel):
    def __init__(self, api_key: str, model_name: str = "glm-4.5-flash"):
        super().__init__(api_key, model_name)
        self.client = ZaiClient(api_key=api_key)
        self.sleep_time = 6
        
    def invoke(
        self,
        prompt: str,
        system_prompt: str | None = None,
        temperature: float = 0.0,
        top_p: float = 1.0,
        max_tokens: int = 8192,
    ):
        try:
            messages = [
                {
                    "role": "system", 
                    "content": "You are a medical NLP system specialized in medical entity extraction from a given radiology report."
                },
                {
                    "role": "user",
                    "content": prompt
                }
            ]

            response = self.client.chat.completions.create(
                model=self.model_name,
                messages=messages,
                temperature=temperature,
                top_p=top_p,
                max_tokens=max_tokens,
                stream=False,
            )

            if response.choices:
                return response.choices[0].message.content.strip()

            return None
        except Exception as e:
            logger.error(f"GLM API error: {e}")
            if hasattr(e, "status_code"):
                logger.error(f"Status code: {e.status_code}")
            if hasattr(e, "body"):
                logger.error(f"Error body: {e.body}")
            return None

# %%
class DeepSeekModel(AIBaseModel):
    def __init__(self, api_key: str, model_name: str = "deepseek-chat"):
        super().__init__(api_key, model_name)
        self.client = OpenAI(
            api_key=api_key,
            base_url="https://api.deepseek.com"
        )
        self.sleep_time = 3
        
    def invoke(
        self,
        prompt: str,
        system_prompt: str | None = None,
        temperature: float = 0.0,
        top_p: float = 1.0,
        max_tokens: int = 8192,
    ):
        try:
            messages = [
                {
                    "role": "system", 
                    "content": "You are a medical NLP system specialized in medical entity extraction from a given radiology report."
                },
                {
                    "role": "user",
                    "content": prompt
                }
            ]

            response = self.client.chat.completions.create(
                model=self.model_name,
                messages=messages,
                temperature=temperature,
                top_p=top_p,
                max_tokens=max_tokens,
                stream=False,
            )

            return response.choices[0].message.content.strip()
        except Exception as e:
            logger.error(f"DeepSeek API error: {e}")
            return None

# %% [markdown]
# ## Get Model

# %%
def get_ai_model(model: str, model_name: str):
    model_map = {
        "gemini": GeminiModel,
        "glm": GLMModel,
        "deepseek": DeepSeekModel
    }
    
    if model not in model_map:
        raise ValueError(f"Unvalid model: {model}. Choices: {list(model_map.keys())}")
    
    return model_map[model](API_KEYS[model], model_name)

# %%
def load_jsonl(path: str):
    with open(path, encoding="utf-8") as file:
        return [json.loads(line) for line in file if line.strip()]

def load_json(path: str):
    with open(path, encoding="utf-8") as file:
        return json.load(file)

# %%
def build_prompt(report: str) -> str:
    return PROMPT_TEMPLATE.replace("<<<REPORT_TEXT>>>", report)

# %%
def safe_parse_json(text: str):
    if not text:
        return None

    text = re.sub(r"```json|```", "", text, flags=re.IGNORECASE).strip()

    try:
        return json.loads(text)
    except json.JSONDecodeError:
        pass

    # önce array yakala
    m = re.search(r"\[.*\]", text, re.S)
    if m:
        try:
            return json.loads(m.group())
        except Exception:
            pass

    # sonra object
    m = re.search(r"\{.*\}", text, re.S)
    if m:
        try:
            return json.loads(m.group())
        except Exception:
            return None

    return None

# %%
def run_inference_radgraph(
    dataset,
    output_path: str,
    model_id: str,
    model_name: str,
):
    model = get_ai_model(model_id, model_name)

    results = []
    for idx, sample in tqdm(enumerate(dataset), total=len(dataset), desc="Processing Samples"):
        
        prompt = build_prompt(sample["report"])

        raw_output = model.invoke(
            prompt=prompt,
            system_prompt=None
        )

        parsed = safe_parse_json(raw_output)

        print(f"Report: {sample['report']}")
        print(f"Parsed Output: {parsed}")
        
        result = {
            "dataset": sample["dataset"],
            "doc_key": sample["doc_key"],
            "report": sample["report"],
            "model": model_name,
            "entities": parsed,
        }
        
        results.append(result)

        if (idx + 1) % 5 == 0:
            temp_path = output_path.replace(".json", "_temp.json")
            with open(temp_path, "w") as f:
                f.write(json.dumps(results))
        

        time.sleep(model.sleep_time + 0.2)

    with open(output_path, "w") as f:
        for r in results:
            f.write(json.dumps(r) + "\n")

    return results

def run_inference_ratener(
    dataset,
    output_path: str,
    model_id: str,
    model_name: str,
):
    model = get_ai_model(model_id, model_name)

    results = []
    for idx, sample in tqdm(enumerate(dataset), total=len(dataset), desc="Processing Samples"):
        
        prompt = build_prompt(sample["report"])

        raw_output = model.invoke(
            prompt=prompt,
            system_prompt=None
        )

        parsed = safe_parse_json(raw_output)

        print(f"Report: {sample['report']}")
        print(f"Raw Output: {raw_output}")
        
        result = {
            "note_id": sample["note_id"],
            "report": sample["report"],
            "model": model_name,
            "entities": parsed,
        }
        
        results.append(result)

        if (idx + 1) % 5 == 0:
            temp_path = output_path.replace(".json", "_temp.json")
            with open(temp_path, "w") as f:
                f.write(json.dumps(results))
        

        time.sleep(model.sleep_time + 0.2)

    with open(output_path, "w") as f:
        for r in results:
            f.write(json.dumps(r) + "\n")

    return results

# %%
INPUT_PATH = "/kaggle/input/random20/radgraphxl-chest-ct-sample-20.json"
OUTPUT_PATH = "/kaggle/working/chest-ct-schema-random20.json"

dataset = load_json(INPUT_PATH)

results = run_inference_radgraph(
    dataset=dataset,
    output_path=OUTPUT_PATH,
    model_id="gemini",
    model_name="gemma-3-27b-it",
)
# Out:
# Processing Samples:   0%|          | 0/18 [00:00<?, ?it/s]
# Report: CT Pulmonary Embolism Chest 12 - 05 - 06 HISTORY : 73 - year - old male with history of renal cell carcinoma now with chest pain and shortness of breath . Possibly pneumonia in the left upper lobe . Evaluate for pulmonary embolism . COMPARISON : CT chest abdomen and pelvis 10 - 19 - 2006 . TECHNIQUE : Multiple contiguous axial images were obtained from the thoracic inlet to the domes of the diaphragms utilizing the standard CT pulmonary embolism chest protocol . 100 mL of Isovue - 300 was given without adverse reaction . Additional 3 - D reconstructed images were performed and reviewed . FINDINGS : Subcentimeter hypodense lesions are seen in the thyroid gland . A large subcarinal lymph node is now noted measuring 21 mm which is new since the prior study . Left hilar / AP window lymphadenopathy has increased in size from prior study , now measuring 3 . 1 x 5 . 1 cm ( previously 2 . 8 x 3 . 8 cm ) . The heart is normal in size . There is no pericardial effusion . Coronary arterial calcifications are present . The aorta is normal in course and caliber . There is conventional branching pattern of the great arch vessels . The left brachiocephalic vein is not well opacified , but there is still the suggestion of a filling defect , likely representing the previously noted thrombus ( 2 / 356 ) . A filling defect is also seen in a right lower lobe subsegmental pulmonary artery ( 2 / 197 ), stable from prior study . Thrombus in the left pulmonary vein has further slightly decreased in size from prior study ( 10 / 19 / 2006 / 30 ) . Evaluation of the lung parenchyma demonstrates interval development of diffuse bilateral patchy ground - glass opacities . There has also been interval development of small bilateral pleural effusions , left greater than right . Visualized images of the upper abdomen demonstrate a stable perihepatic implant ( 10 / 19 / 06 / 45 ) . The large bilateral adrenal metastases are also stable . The patient is again noted to be status post right nephrectomy . The previously noted thrombus in the inferior vena cava is not well visualized due to the arterial phase of the study . The visualized osseous structures again demonstrate a sclerotic lesion in the T11 vertebral body , stable from prior study . Right rotator cuff repair is again noted . The remaining visualized osseous structures demonstrate degenerative changes . IMPRESSION : 1 . INTERVAL DEVELOPMENT OF DIFFUSE DENSE BILATERAL GROUNDGLASS OPACITIES , NONSPECIFIC BUT MAY BE DUE TO INFECTION OR POSSIBLY DRUG REACTION . 2 . INTERVAL DEVELOPMENT OF SMALL BILATERAL PLEURAL EFFUSIONS . 3 . STABLE RIGHT LOWER LOBE SUBSEGMENTAL PULMONARY EMBOLUS . 4 . INTERVAL DECREASE IN SIZE OF LEFT INFERIOR PULMONARY VEIN THROMBUS . 5 . LEFT BRACHIOCEPHALIC VEIN NOT WELL - OPACIFIED , AND PREVIOUSLY NOTED THROMBUS IS NOT WELL VISUALIZED BUT IS STILL LIKELY PRESENT . 6 . INTERVAL INCREASE OF MEDIASTINAL LYMPHADENOPATHY COMPATIBLE WITH PROGRESSION OF METASTATIC DISEASE . 7 . PREVIOUSLY NOTED THROMBUS IN THE INFERIOR VENA CAVA NOT VISUALIZED DUE TO PHASE OF INTRAVENOUS CONTRAST ADMINISTRATION . 8 . STABLE RIGHT PERIHEPATIC NODULE AND BILATERAL ADRENAL METASTASIS . 9 . STABLE SCLEROTIC LESION IN THE T11 VERTEBRAL BODY . SUMMARY : 4 - POSSIBLE SIGNIFICANT FINDING , MAY NEED ACTION I have personally reviewed the images for this examination and agreed with the report transcribed above .
# Parsed Output: [{'general_finding': 'thyroid nodules', 'specific_finding': 'hypodense lesions', 'finding_presence': 'present', 'location': ['thyroid gland'], 'degree': ['subcentimeter'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'lymphadenopathy', 'specific_finding': 'subcarinal lymph node enlargement', 'finding_presence': 'present', 'location': ['subcarina'], 'degree': ['large'], 'measurement': '21 mm', 'comparison': 'new'}, {'general_finding': 'lymphadenopathy', 'specific_finding': 'left hilar / AP window lymph node enlargement', 'finding_presence': 'present', 'location': ['left hilum', 'AP window'], 'degree': [], 'measurement': '3.1 x 5.1 cm', 'comparison': 'increased'}, {'general_finding': 'heart', 'specific_finding': 'heart size', 'finding_presence': 'present', 'location': [], 'degree': ['normal'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'pericardial effusion', 'specific_finding': 'pericardial effusion', 'finding_presence': 'absent', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'coronary artery calcification', 'specific_finding': 'coronary artery calcifications', 'finding_presence': 'present', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'aorta', 'specific_finding': 'aorta course and caliber', 'finding_presence': 'present', 'location': [], 'degree': ['normal'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'pulmonary embolus', 'specific_finding': 'filling defect', 'finding_presence': 'present', 'location': ['left brachiocephalic vein'], 'degree': [], 'measurement': 'None', 'comparison': 'stable'}, {'general_finding': 'pulmonary embolus', 'specific_finding': 'filling defect', 'finding_presence': 'present', 'location': ['right lower lobe subsegmental pulmonary artery'], 'degree': [], 'measurement': 'None', 'comparison': 'stable'}, {'general_finding': 'thrombus', 'specific_finding': 'thrombus', 'finding_presence': 'present', 'location': ['left pulmonary vein'], 'degree': [], 'measurement': 'None', 'comparison': 'decreased'}, {'general_finding': 'lung parenchyma', 'specific_finding': 'ground-glass opacities', 'finding_presence': 'present', 'location': ['bilateral lungs'], 'degree': ['diffuse', 'patchy'], 'measurement': 'None', 'comparison': 'interval development'}, {'general_finding': 'pleural effusion', 'specific_finding': 'pleural effusion', 'finding_presence': 'present', 'location': ['bilateral pleura'], 'degree': ['small', 'bilateral'], 'measurement': 'None', 'comparison': 'interval development'}, {'general_finding': 'perihepatic implant', 'specific_finding': 'perihepatic implant', 'finding_presence': 'present', 'location': ['perihepatic'], 'degree': ['stable'], 'measurement': 'None', 'comparison': 'stable'}, {'general_finding': 'adrenal metastasis', 'specific_finding': 'adrenal metastases', 'finding_presence': 'present', 'location': ['bilateral adrenal glands'], 'degree': ['large', 'bilateral', 'stable'], 'measurement': 'None', 'comparison': 'stable'}, {'general_finding': 'prior disease', 'specific_finding': 'status post right nephrectomy', 'finding_presence': 'present', 'location': ['right kidney'], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'thrombus', 'specific_finding': 'thrombus', 'finding_presence': 'uncertain', 'location': ['inferior vena cava'], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'bone', 'specific_finding': 'sclerotic lesion', 'finding_presence': 'present', 'location': ['T11 vertebral body'], 'degree': ['stable'], 'measurement': 'None', 'comparison': 'stable'}, {'general_finding': 'bone', 'specific_finding': 'degenerative changes', 'finding_presence': 'present', 'location': ['visualized osseous structures'], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'right rotator cuff repair', 'specific_finding': 'right rotator cuff repair',  ...
# Processing Samples:   6%|▌         | 1/18 [00:32<09:08, 32.25s/it]
# Report: Addendum Begins Coronal and sagittal MPR and MIP reformations were performed on an off - line 3D workstation and corroborate the findings . Addendum Ends CT PULMONARY ANGIOGRAM : 1 / 20 / 2021 COMPARISON : None . CLINICAL HISTORY : Acute on chronic dyspnea . TECHNIQUE : After administration of IV contrast , a pulmonary CT angiogram was obtained . FINDINGS : VASCULAR : Evaluation is limited at the bases of the lungs by motion . No evidence of pulmonary embolism . The pulmonary artery measures 27 mm in diameter , which is within normal limits . There is a tight stenosis of the origin of the left carotid artery and a mild stenosis of the left subclavian artery , just distal to its origin . Diffuse aortic calcifications are seen . In addition , there is a small splenic artery aneurysm at the splenic hilum measuring 10 mm in diameter . The aneurysm is heavily calcified peripherally . CHEST AND MEDIASTINUM : There is severe centrilobular emphysema , trending towards being panlobular in distribution . Superimposed upon this , there is a region of focal septal thickening in the right upper lobe posteriorly that may represent infection . Small bilateral pleural effusions are seen , associated with atelectasis versus early consolidation . There is a small calcified pleural nodule at the apex of the left lung . No other nodules are seen within the lungs . ABDOMEN : Air is seen within what is most likely the biliary system . There is a stomach distended with air and fluid . Other visualized upper abdominal structures are unremarkable , though this is a limited evaluation at the arterial phase of contrast enhancement . BONES : Visualized bones are unremarkable . IMPRESSION : 1 . NO EVIDENCE OF PULMONARY EMBOLISM . 2 . SEPTAL THICKENING AND GROUNDGLASS OPACITY IN THE RIGHT UPPER LOBE POSTERIORLY THAT MAY REPRESENT SUPERIMPOSED INFECTION , ON A BACKGROUND OF SEVERE EMPHYSEMATOUS . 3 . SMALL BILATERAL PLEURAL EFFUSIONS , ASSOCIATED WITH BIBASILAR ATELECTASIS . 4 . TIGHT STENOSIS OF THE ORIGIN OF THE LEFT CAROTID ARTERY . SUMMARY : 4 - POSSIBLE SIGNIFICANT FINDINGS , MAY NEED ACTION I have personally reviewed the images for this examination and agreed with the report transcribed above .
# Parsed Output: [{'general_finding': 'pulmonary embolus', 'specific_finding': 'pulmonary embolus', 'finding_presence': 'absent', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'pulmonary artery', 'specific_finding': 'pulmonary artery diameter', 'finding_presence': 'present', 'location': [], 'degree': ['normal'], 'measurement': '27 mm', 'comparison': 'None'}, {'general_finding': 'carotid artery', 'specific_finding': 'stenosis', 'finding_presence': 'present', 'location': ['left carotid artery origin'], 'degree': ['tight'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'subclavian artery', 'specific_finding': 'stenosis', 'finding_presence': 'present', 'location': ['left subclavian artery'], 'degree': ['mild'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'aorta', 'specific_finding': 'aortic calcifications', 'finding_presence': 'present', 'location': [], 'degree': ['diffuse'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'splenic artery aneurysm', 'specific_finding': 'splenic artery aneurysm', 'finding_presence': 'present', 'location': ['splenic hilum'], 'degree': ['small', 'heavily calcified'], 'measurement': '10 mm', 'comparison': 'None'}, {'general_finding': 'lung parenchyma', 'specific_finding': 'emphysema', 'finding_presence': 'present', 'location': [], 'degree': ['severe', 'centrilobular', 'panlobular'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'lung parenchyma', 'specific_finding': 'septal thickening', 'finding_presence': 'present', 'location': ['right upper lobe posteriorly'], 'degree': ['focal'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'infection', 'specific_finding': 'infection', 'finding_presence': 'uncertain', 'location': ['right upper lobe posteriorly'], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'pleural effusion', 'specific_finding': 'pleural effusion', 'finding_presence': 'present', 'location': ['bilateral'], 'degree': ['small'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'atelectasis', 'specific_finding': 'atelectasis', 'finding_presence': 'present', 'location': ['bilateral'], 'degree': ['bibasilar'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'consolidation', 'specific_finding': 'consolidation', 'finding_presence': 'uncertain', 'location': ['bilateral'], 'degree': ['early'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'pleural nodule', 'specific_finding': 'pleural nodule', 'finding_presence': 'present', 'location': ['left lung apex'], 'degree': ['small', 'calcified'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'air', 'specific_finding': 'air', 'finding_presence': 'present', 'location': ['biliary system'], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'stomach', 'specific_finding': 'distension', 'finding_presence': 'present', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'upper abdominal organs', 'specific_finding': 'upper abdominal organs', 'finding_presence': 'present', 'location': [], 'degree': ['unremarkable'], 'measurement': 'None', 'comparison': 'None'}]
# Processing Samples:  11%|█         | 2/18 [01:01<08:04, 30.26s/it]
# Report: EXAM : CT Pulmonary Embolism Chest Only JANUARY 21 , 2002 2 : 12 PM CLINICAL HISTORY : R / o PE COMPARISON : 00 , December 27th CONTRAST : 111 mL of Isovue 370 TECHNIQUE : After the uneventful administration of IV contrast , contiguous axial images were acquired through the thorax during the pulmonary arterial phase at 1 . 25 mm and 5 mm slice slice thicknesses . Axial images were then acquired from the pelvis to the knees during the systemic venous phase . Sagittal , coronal , and maximum intensity projection were performed also obtained . Multiplanar reformations and maximum intensity projections were performed on an independent 3D workstation and corroborate the findings . FINDINGS : The heart size is normal without a pericardial effusion . The aorta and great vessels are normal in course and caliber . The pulmonary arterial tree is well opacified , without filling defects to suggest pulmonary embolism . The main pulmonary artery is normal in course and caliber . Scattered areas of ground - glass opacity are seen throughout the right lung likely representing atelectasis . Stable appearance of a 5 - mm ground - glass nodule in the right apex . No pleural effusions . The airways are patent and of normal course and caliber . No mediastinal , hilar or axillary lymphadenopathy . Limited evaluation of the upper abdomen and is unremarkable . No suspicious bony lesions identified . IMPRESSION : 1 . NO EVIDENCE OF PULMONARY EMBOLISM . 2 . STABLE APPEARANCE OF A 5 - MM GROUND GLASS NODULE WITHIN THE RIGHT APEX SINCE 12 - 1 - 2000 . SUMMARY : 2 - ABNORMAL , PREVIOUSLY REPORTED I have personally reviewed the images for this examination and agreed with the report transcribed above .
# Parsed Output: [{'general_finding': 'heart', 'specific_finding': 'heart size', 'finding_presence': 'present', 'location': [], 'degree': ['normal'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'pericardial effusion', 'specific_finding': 'pericardial effusion', 'finding_presence': 'absent', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'aorta', 'specific_finding': 'aorta course and caliber', 'finding_presence': 'present', 'location': [], 'degree': ['normal'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'great vessels', 'specific_finding': 'great vessels course and caliber', 'finding_presence': 'present', 'location': [], 'degree': ['normal'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'pulmonary embolus', 'specific_finding': 'filling defects', 'finding_presence': 'absent', 'location': ['pulmonary arteries'], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'pulmonary artery', 'specific_finding': 'course and caliber', 'finding_presence': 'present', 'location': [], 'degree': ['normal'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'lung parenchyma', 'specific_finding': 'ground-glass opacity', 'finding_presence': 'present', 'location': ['right lung'], 'degree': ['scattered'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'pulmonary nodule', 'specific_finding': 'nodule', 'finding_presence': 'present', 'location': ['right apex'], 'degree': ['5 - mm', 'stable'], 'measurement': '5 mm', 'comparison': 'stable'}, {'general_finding': 'pleural effusion', 'specific_finding': 'pleural effusion', 'finding_presence': 'absent', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'airways', 'specific_finding': 'patency', 'finding_presence': 'present', 'location': [], 'degree': ['normal'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'lymphadenopathy', 'specific_finding': 'lymphadenopathy', 'finding_presence': 'absent', 'location': ['mediastinal', 'hilar', 'axillary'], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'upper abdomen', 'specific_finding': 'upper abdomen', 'finding_presence': 'present', 'location': [], 'degree': ['unremarkable'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'bone', 'specific_finding': 'bony lesions', 'finding_presence': 'absent', 'location': [], 'degree': ['suspicious'], 'measurement': 'None', 'comparison': 'None'}]
# Processing Samples:  17%|█▋        | 3/18 [01:32<07:40, 30.67s/it]
# Report: CHEST CT : 9 / 27 / 2014 CLINICAL HISTORY : A 68 - year - old male with history of bronchiectasis . Follow - up . COMPARISON : 4 - 10 - 14 . TECHNIQUE : Unenhanced discontiguous axial high resolution CT imaging of the chest from the thoracic inlet to the upper abdomen including prone and supine positioning . FINDINGS : Mild coronary artery calcification is again noted . There is no pericardial or pleural effusion . The unenhanced appearance of the heart and thoracic vasculature is otherwise unremarkable . No suspicious , new mediastinal , hilar , or axillary adenopathy is identified . The central airways appear patent . There has been an interval increase in centrilobular ground - glass nodules within the left lower lobe , which is incompletely visualized , and likely related to infection and / or aspiration . The visualized lungs are otherwise unchanged . This includes an approximately 2 . 7 x 1 . 4 cm opacity with associated bronchiectasis in the posterior segment of the right lower lobe , which may represent an area of scarring and / or chronic atelectasis . Small , calcified granulomas are unchanged . A 5 mm pulmonary nodule in the azygoesophageal recess is unchanged . Areas of bronchial wall thickening , mild bronchiectasis , mucus plugging and associated centrilobular nodules particularly within the right upper and right lower lobes are unchanged . Associated , tiny calcifications in the region of these airways are also unchanged . No new suspicious pulmonary nodule , consolidation , pneumothorax , or pulmonary edema is identified . A few colonic diverticula are incidentally noted . The visualized upper abdomen is otherwise grossly unremarkable . The visualized osseous structures are unchanged , with no new suspicious focal bony lesions identified . Degenerative changes are redemonstrated . IMPRESSION : 1 . INCREASED LEFT LOWER LOBE CENTRILOBULAR GROUND - GLASS NODULES , INCOMPLETELY VISUALIZED AND COMPATIBLE WITH INFECTION AND / OR ASPIRATION . CORRELATE CLINICALLY . 2 . OTHERWISE , STABLE EXAMINATION WITH REDEMONSTRATION OF PREDOMINANTLY RIGHT - SIDED BRONCHIAL WALL THICKENING , MUCUS PLUGGING , MILD BRONCHIECTASIS AND ASSOCIATED CENTRILOBULAR NODULES . 3 . STABLE 2 . 7 X 1 . 4 CM PERIPHERAL RIGHT LOWER LOBE OPACITY , INCOMPLETELY VISUALIZED . 4 . STABLE 5 MM RIGHT LOWER LOBE NODULE . SUMMARY : 4 - POSSIBLE SIGNIFICANT FINDINGS , MAY NEED ACTION I have personally reviewed the images for this examination and agreed with the report transcribed above .
# Parsed Output: [{'general_finding': 'coronary artery calcification', 'specific_finding': 'coronary artery calcification', 'finding_presence': 'present', 'location': [], 'degree': ['mild'], 'measurement': 'None', 'comparison': 'stable'}, {'general_finding': 'pericardial effusion', 'specific_finding': 'pericardial effusion', 'finding_presence': 'absent', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'pleural effusion', 'specific_finding': 'pleural effusion', 'finding_presence': 'absent', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'heart', 'specific_finding': 'heart appearance', 'finding_presence': 'present', 'location': [], 'degree': ['unremarkable'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'thoracic vasculature', 'specific_finding': 'thoracic vasculature appearance', 'finding_presence': 'present', 'location': [], 'degree': ['unremarkable'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'lymphadenopathy', 'specific_finding': 'lymphadenopathy', 'finding_presence': 'absent', 'location': ['mediastinal', 'hilar', 'axillary'], 'degree': ['suspicious', 'new'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'central airways', 'specific_finding': 'patency', 'finding_presence': 'present', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'ground-glass nodules', 'specific_finding': 'centrilobular ground-glass nodules', 'finding_presence': 'present', 'location': ['left lower lobe'], 'degree': ['interval increase'], 'measurement': 'None', 'comparison': 'increased'}, {'general_finding': 'lung parenchyma', 'specific_finding': 'opacity', 'finding_presence': 'present', 'location': ['posterior segment of the right lower lobe'], 'degree': [], 'measurement': '2.7 x 1.4 cm', 'comparison': 'unchanged'}, {'general_finding': 'consolidation', 'specific_finding': 'consolidation', 'finding_presence': 'uncertain', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'atelectasis', 'specific_finding': 'atelectasis', 'finding_presence': 'uncertain', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'pulmonary nodules', 'specific_finding': 'calcified granulomas', 'finding_presence': 'present', 'location': [], 'degree': ['small', 'calcified'], 'measurement': 'None', 'comparison': 'unchanged'}, {'general_finding': 'pulmonary nodule', 'specific_finding': 'pulmonary nodule', 'finding_presence': 'present', 'location': ['azygoesophageal recess'], 'degree': ['small'], 'measurement': '5 mm', 'comparison': 'unchanged'}, {'general_finding': 'airways', 'specific_finding': 'bronchial wall thickening', 'finding_presence': 'present', 'location': ['right upper lobe', 'right lower lobe'], 'degree': ['mild'], 'measurement': 'None', 'comparison': 'unchanged'}, {'general_finding': 'airways', 'specific_finding': 'mucus plugging', 'finding_presence': 'present', 'location': ['right upper lobe', 'right lower lobe'], 'degree': [], 'measurement': 'None', 'comparison': 'unchanged'}, {'general_finding': 'lung parenchyma', 'specific_finding': 'centrilobular nodules', 'finding_presence': 'present', 'location': ['right upper lobe', 'right lower lobe'], 'degree': [], 'measurement': 'None', 'comparison': 'unchanged'}, {'general_finding': 'airways', 'specific_finding': 'calcifications', 'finding_presence': 'present', 'location': [], 'degree': ['tiny'], 'measurement': 'None', 'comparison': 'unchanged'}, {'general_finding': 'pulmonary nodule', 'specific_finding': 'pulmonary nodule', 'finding_presence': 'absent', 'location': [], 'degree': ['suspicious', 'new'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'consolidation', 'specific_finding': 'consolidation', 'finding_presence': 'absent', 'location': [], 'degree': ['new'], 'measurement': 'None', 'comparison': 'None'}, {'genera ...
# Processing Samples:  22%|██▏       | 4/18 [02:18<08:34, 36.74s/it]
# Report: CT Pulmonary Embolism Chest Only 1 / 21 / 2005 11 : 48 PM HISTORY : tachycardia , history of left thigh sarcoma COMPARISON : CT chest abdomen and pelvis 01 - 16 - 2005 TECHNIQUE : Multiplanar contrast - enhanced angiogram of the chest in pulmonary arterial phase was obtained after the uneventful administration of 110 mL Isovue 370 IV contrast . Curved planar reformats , volume rendered , and maximum intensity projection images were performed on an independent 3 - D workstation . FINDINGS : Exam is limited due to respiratory motion at the lung bases . The visualized thyroid gland is unremarkable . The main pulmonary artery is of normal caliber and there are no filling defects within the pulmonary arteries . The heart is normal in size , with a normal branching pattern of the great vessels . No pericardial effusion . Visualized great vessels and the thoracic and visualized abdominal aorta are of normal caliber . There are prominent axillary lymph nodes bilaterally , similar to prior exam , measuring up to 6 mm in short axis diameter . A 6 millimeter right paratracheal lymph node is unchanged . No abnormally enlarged mediastinal or hilar lymph nodes . Multiple bilateral pulmonary nodules are not significantly changed in size , with index nodules as follows : Left upper lobe nodule ( 2 / 393 ) measures 1 . 3 x 1 . 1 cm , previously 1 . 3 x 1 . 0 cm ; left lower lobe nodule ( 2 / 278 ) currently measures 1 . 2 x 1 . 1 cm , previously 1 . 1 cm ; right middle lobe nodule ( 2 / 350 ) currently measures 1 . 5 x 1 . 3 cm , previously 1 . 5 x 1 . 1 cm ; right lower lobe nodule ( 4 / 27 ) currently measures 1 . 2 cm , previously 1 . 2 x 1 . 3 cm . Interval resolution of previously noted left pleural effusion . No pneumothorax . Limited evaluation of the upper abdomen in pulmonary arterial contrast phase demonstrates no gross abnormalities . Visualized osseous structures are unremarkable , without focal suspicious lesion . IMPRESSION : 1 . NO EVIDENCE OF PULMONARY EMBOLISM WITHIN LIMITATIONS OF THE EXAM . 2 . MULTIPLE BILATERAL PULMONARY NODULES , CONSISTENT WITH METASTATIC DISEASE , ARE NOT SIGNIFICANTLY CHANGED . SUMMARY : 2 - ABNORMAL , PREVIOUSLY REPORTED I have personally reviewed the images for this examination and agreed with the report transcribed above .
# Parsed Output: [{'general_finding': 'thyroid gland', 'specific_finding': 'thyroid gland', 'finding_presence': 'present', 'location': [], 'degree': ['unremarkable'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'pulmonary artery', 'specific_finding': 'filling defects', 'finding_presence': 'absent', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'heart', 'specific_finding': 'heart size', 'finding_presence': 'present', 'location': [], 'degree': ['normal'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'great vessels', 'specific_finding': 'branching pattern', 'finding_presence': 'present', 'location': [], 'degree': ['normal'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'pericardial effusion', 'specific_finding': 'pericardial effusion', 'finding_presence': 'absent', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'great vessels', 'specific_finding': 'great vessels caliber', 'finding_presence': 'present', 'location': [], 'degree': ['normal'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'thoracic aorta', 'specific_finding': 'aorta caliber', 'finding_presence': 'present', 'location': [], 'degree': ['normal'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'abdominal aorta', 'specific_finding': 'aorta caliber', 'finding_presence': 'present', 'location': [], 'degree': ['normal'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'lymph nodes', 'specific_finding': 'axillary lymph nodes', 'finding_presence': 'present', 'location': ['bilaterally'], 'degree': ['prominent'], 'measurement': 'up to 6 mm', 'comparison': 'similar'}, {'general_finding': 'lymph nodes', 'specific_finding': 'paratracheal lymph node', 'finding_presence': 'present', 'location': ['right'], 'degree': [], 'measurement': '6 mm', 'comparison': 'unchanged'}, {'general_finding': 'lymph nodes', 'specific_finding': 'mediastinal or hilar lymph nodes', 'finding_presence': 'absent', 'location': [], 'degree': ['enlarged'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'pulmonary nodules', 'specific_finding': 'pulmonary nodules', 'finding_presence': 'present', 'location': ['bilateral'], 'degree': ['multiple'], 'measurement': 'None', 'comparison': 'not significantly changed'}, {'general_finding': 'pulmonary nodule', 'specific_finding': 'pulmonary nodule', 'finding_presence': 'present', 'location': ['left upper lobe'], 'degree': [], 'measurement': '1.3 x 1.1 cm', 'comparison': 'previously 1.3 x 1.0 cm'}, {'general_finding': 'pulmonary nodule', 'specific_finding': 'pulmonary nodule', 'finding_presence': 'present', 'location': ['left lower lobe'], 'degree': [], 'measurement': '1.2 x 1.1 cm', 'comparison': 'previously 1.1 cm'}, {'general_finding': 'pulmonary nodule', 'specific_finding': 'pulmonary nodule', 'finding_presence': 'present', 'location': ['right middle lobe'], 'degree': [], 'measurement': '1.5 x 1.3 cm', 'comparison': 'previously 1.5 x 1.1 cm'}, {'general_finding': 'pulmonary nodule', 'specific_finding': 'pulmonary nodule', 'finding_presence': 'present', 'location': ['right lower lobe'], 'degree': [], 'measurement': '1.2 cm', 'comparison': 'previously 1.2 x 1.3 cm'}, {'general_finding': 'pleural effusion', 'specific_finding': 'pleural effusion', 'finding_presence': 'absent', 'location': ['left'], 'degree': [], 'measurement': 'None', 'comparison': 'interval resolution'}, {'general_finding': 'pneumothorax', 'specific_finding': 'pneumothorax', 'finding_presence': 'absent', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'upper abdomen', 'specific_finding': 'gross abnormalities', 'finding_presence': 'absent', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'bone', 'specific_finding': 'osseous structures', 'finding_presence': 'present', 'location': [],  ...
# Processing Samples:  28%|██▊       | 5/18 [02:53<07:50, 36.23s/it]
# Report: STUDY : CT chest high - resolution 03 / 24 / 20 at 1150 hrs HISTORY : 70 - year - old female with history of pulmonary fibrosis . Follow - up examination . COMPARISON : None TECHNIQUE : Multiple 1 mm axial CT images of the chest were obtained every 10 mm in the supine position and every 20 mm in the prone position . FINDINGS : Visualized portions of the thyroid gland are unremarkable . No supraclavicular , axillary , or mediastinal lymphadenopathy . Lack of intravenous contrast limits evaluation of the hila . Ascending aortic caliber is normal . The main pulmonary artery measures 35 mm in diameter , which is dilated and suggestive of pulmonary arterial hypertension . Heart is normal in size . No pericardial effusion . There is coronary and thoracic aortic arteriosclerosis . Mitral and aortic annular calcification is incidentally noted . Evaluation of the lung parenchyma demonstrates extensive peribronchial thickening , irregular parenchymal lines , peripheral intralobular and sublobular reticulation , accompanied by areas of occasional architectural distortion and microcystic honeycombing , particularly noted within the mid and upper lung zones . There is mild traction bronchiectasis and bronchiolectasis , not appreciably out of proportion relative to surrounding parenchymal disease . No significant ground - glass or consolidative lung disease . Lung parenchyma demonstrates an overall mosaic attenuation pattern on the provided inspiratory phase images ; however , expiratory phase imaging was not performed for assessment of air - trapping degree or extent . Pulmonary architectural lines are identified within the more radiolucent lobules , although intralobular broncho - arteriolar structures do appear relatively attenuated . Although not entirely confirmatory without expiratory phase imaging , pattern suggests hyperinflated radiolucent lobules with admixture of normal lung parenchyma , rather than true ground - glass lung disease . No discrete suspicious pulmonary nodules . No pleural effusions . Trachea and central airways are patent . There is a small sliding - type hiatal hernia with mild circumferential thickening of the more proximal thoracic esophagus , potentially findings of reflux esophagitis . Correlation with the patient ' s history and signs / symptoms of potential gastroesophageal reflux disease is suggested . Limited images of the abdomen are unremarkable . Bones and soft tissues are unremarkable . IMPRESSION : PATTERN OF LUNG DISEASE PRIMARILY CHARACTERIZED BY DIFFUSE MOSAIC PARENCHYMAL ATTENUATION WITH PROBABLE AIR - TRAPPING ( EXPIRATORY PHASE IMAGING NOT PERFORMED ) AND IRREGULAR LINEAR OPACITIES WITH RELATIVE PRESERVATION OF LUNG ARCHITECTURE AND LACK OF FRANK HONEYCOMBING . FINDINGS ARE ATYPICAL FOR USUAL INTERSTITIAL PNEUMONIA ( UIP ) AND MAY BE MORE CHARACTERISTIC OF CHRONIC HYPERSENSITIVITY PNEUMONITIS , DRUG - INDUCED LUNG INJURY , OR PERHAPS COLLAGEN VASCULAR DISEASE . SUMMARY : 4 - POSSIBLE SIGNIFICANT FINDING , MAY NEED ACTION I have personally reviewed the images for this examination and agreed with the report transcribed above .
# Parsed Output: [{'general_finding': 'thyroid gland', 'specific_finding': 'thyroid gland', 'finding_presence': 'present', 'location': [], 'degree': ['unremarkable'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'lymphadenopathy', 'specific_finding': 'lymphadenopathy', 'finding_presence': 'absent', 'location': ['supraclavicular', 'axillary', 'mediastinal'], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'aorta', 'specific_finding': 'ascending aortic caliber', 'finding_presence': 'present', 'location': ['ascending aorta'], 'degree': ['normal'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'pulmonary artery', 'specific_finding': 'pulmonary artery diameter', 'finding_presence': 'present', 'location': ['main pulmonary artery'], 'degree': ['dilated'], 'measurement': '35 mm', 'comparison': 'None'}, {'general_finding': 'pulmonary arterial hypertension', 'specific_finding': 'pulmonary arterial hypertension', 'finding_presence': 'present', 'location': [], 'degree': ['suggestive'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'heart', 'specific_finding': 'heart size', 'finding_presence': 'present', 'location': [], 'degree': ['normal'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'pericardial effusion', 'specific_finding': 'pericardial effusion', 'finding_presence': 'absent', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'atherosclerotic plaque', 'specific_finding': 'arteriosclerosis', 'finding_presence': 'present', 'location': ['coronary arteries', 'thoracic aorta'], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'aortic annular calcification', 'specific_finding': 'aortic annular calcification', 'finding_presence': 'present', 'location': ['aortic annulus'], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'mitral annular calcification', 'specific_finding': 'mitral annular calcification', 'finding_presence': 'present', 'location': ['mitral annulus'], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'lung parenchyma', 'specific_finding': 'peribronchial thickening', 'finding_presence': 'present', 'location': [], 'degree': ['extensive'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'lung parenchyma', 'specific_finding': 'irregular parenchymal lines', 'finding_presence': 'present', 'location': [], 'degree': ['irregular'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'lung parenchyma', 'specific_finding': 'peripheral intralobular and sublobular reticulation', 'finding_presence': 'present', 'location': [], 'degree': ['peripheral'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'lung parenchyma', 'specific_finding': 'architectural distortion', 'finding_presence': 'present', 'location': [], 'degree': ['occasional'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'lung parenchyma', 'specific_finding': 'microcystic honeycombing', 'finding_presence': 'present', 'location': ['mid lung zones', 'upper lung zones'], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'bronchiectasis', 'specific_finding': 'traction bronchiectasis', 'finding_presence': 'present', 'location': [], 'degree': ['mild'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'bronchiolectasis', 'specific_finding': 'bronchiolectasis', 'finding_presence': 'present', 'location': [], 'degree': ['mild'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'consolidation', 'specific_finding': 'consolidation', 'finding_presence': 'absent', 'location': [], 'degree': ['significant'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'ground-glass opacity', 'specific_finding': 'ground-glass opacity', 'finding_presence': 'absent', 'location': [], 'degree': ['significant'], 'measuremen ...
# Processing Samples:  33%|███▎      | 6/18 [03:47<08:27, 42.27s/it]
# Report: CT ANGIOGRAM CHEST CLINICAL HISTORY : Hypoxia . COMPARISON STUDY : Multiple prior CT scans , most recently from 9 / 20 / 2016 . TECHNIQUE : Following the IV administration of 95 cc of Isovue 370 , CT scan of the chest was performed from the thoracic inlet to the upper abdomen using a pulmonary embolus protocol . 3D reformations consisting of curved and multiplanar reformations , maximum intensity projections , and volume rendered images were performed on an independent workstation and corroborate the findings . IV contrast was administered without complication . FINDINGS : Thyroid : Imaged portions of the thyroid gland are unremarkable . Arch : The thoracic aorta is normal in caliber and demonstrates standard 3 - vessel arch anatomy . Heart : The heart is normal in size and configuration , without pericardial effusion . Pulmonary Vasculature : There is no evidence of pulmonary embolus in the main , lobar , or segmental pulmonary arteries . Lungs / Pleura : There is a 2 - mm pulmonary nodule in the right apex best seen on series 4 image # 270 , and a 2 - mm nodule at the left apex best seen on image # 274 . These nodules are unchanged when compared to prior studies . Linear atelectasis is noted at the left lung base . Mild and nonspecific bronchial wall thickening is seen in the lower lobes . No focal airspace consolidation or pleural effusion is seen . Mediastinum : There is no mediastinal lymphadenopathy . Hila : Clear . Axillae : Clear . Upper abdomen : Multiple ill - defined hypervascular hepatic lesions are again seen , and were better characterized on a dedicated abdominal CT from 9 / 20 / 2016 . Skeletal structures : Sclerotic lesions in the in the manubrium , left anterior 6th rib , and T9 are unchanged . IMPRESSION : 1 . THERE IS NO EVIDENCE OF PULMONARY EMBOLUS IN THE MAIN , LOBAR , OR SEGMENTAL PULMONARY ARTERIES . 2 . SMALL NONSPECIFIC APICAL PULMONARY NODULES ARE CHANGED COMPARED TO 9 - 20 - 2016 . 3 . MULTIPLE HYPERVASCULAR LIVER LESIONS ARE PARTIALLY IMAGED . THESE WERE BETTER CHARACTERIZED ON THE 9 - 20 - 16 EXAMINATION . 4 . NO CHANGE IN SCLEROTIC BONE LESIONS . Preliminary findings were reported on 11 - 26 - 2016 at 14 : 14 . SUMMARY : 2 - ABNORMAL , PREVIOUSLY REPORTED I have personally reviewed the images for this examination and agreed with the report transcribed above .
# Parsed Output: [{'general_finding': 'thyroid gland', 'specific_finding': 'thyroid gland', 'finding_presence': 'present', 'location': [], 'degree': ['unremarkable'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'thoracic aorta', 'specific_finding': 'aorta caliber', 'finding_presence': 'present', 'location': [], 'degree': ['normal'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'heart', 'specific_finding': 'heart size and configuration', 'finding_presence': 'present', 'location': [], 'degree': ['normal'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'pericardial effusion', 'specific_finding': 'pericardial effusion', 'finding_presence': 'absent', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'pulmonary embolus', 'specific_finding': 'pulmonary embolus', 'finding_presence': 'absent', 'location': ['main pulmonary arteries', 'lobar pulmonary arteries', 'segmental pulmonary arteries'], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'pulmonary nodules', 'specific_finding': 'pulmonary nodule', 'finding_presence': 'present', 'location': ['right apex', 'left apex'], 'degree': ['2-mm'], 'measurement': '2 mm', 'comparison': 'stable'}, {'general_finding': 'atelectasis', 'specific_finding': 'linear atelectasis', 'finding_presence': 'present', 'location': ['left lung base'], 'degree': ['linear'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'airways', 'specific_finding': 'bronchial wall thickening', 'finding_presence': 'present', 'location': ['lower lobes'], 'degree': ['mild', 'nonspecific'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'lung parenchyma', 'specific_finding': 'consolidation, effusion', 'finding_presence': 'absent', 'location': [], 'degree': ['focal'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'lymphadenopathy', 'specific_finding': 'lymphadenopathy', 'finding_presence': 'absent', 'location': ['mediastinum'], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'liver', 'specific_finding': 'hypervascular hepatic lesions', 'finding_presence': 'present', 'location': [], 'degree': ['ill-defined', 'multiple'], 'measurement': 'None', 'comparison': 'stable'}, {'general_finding': 'bone', 'specific_finding': 'sclerotic lesions', 'finding_presence': 'present', 'location': ['manubrium', 'left anterior 6th rib', 'T9'], 'degree': [], 'measurement': 'None', 'comparison': 'stable'}]
# Processing Samples:  39%|███▉      | 7/18 [04:06<06:22, 34.77s/it]
# Report: Addendum Begins MPR reformations and maximum intensity projections were performed on an independent 3D workstation and corroborate the findings . Addendum Ends CT ANGIOGRAM OF THE CHEST : OCTOBER 2006 COMPARISON : CT chest , abdomen and pelvis on 12 / 28 / 1997 , PET / CT on 2003 - 11 - 20 . CLINICAL HISTORY : A 45 - year - old man with history of papillary thyroid cancer and melanoma , presenting with shortness of breath . TECHNIQUE : Multiple 1 . 25 mm axial images of the thorax were obtained after the uneventful administration of IV contrast in the pulmonary arterial phase . Coronal and sagittal reformats were performed . FINDINGS : Evaluation of the pulmonary arteries demonstrates no filling defects to suggest pulmonary embolism . Evaluation of the mediastinum demonstrates surgical clips in the thyroid bed , compatible with previous thyroidectomy . Small amount of flat , non - confluent fibrofatty soft tissue is seen in the prevascular space , presumed to represent some residual thymic tissue . Heart size is within normal limits with no pericardial effusions . No significant axillary , mediastinal or hilar adenopathy is seen . Evaluation of the lung parenchyma demonstrates a 4 mm left lower lobe nodule along the major fissure , similar in appearance to the exams on 11 / 20 / 2003 and 12 - 28 - 1997 accounting for differences in technique . No focal lung opacities or pleural effusions are seen . Limited evaluation of some of the upper abdominal structures is unremarkable . Evaluation of the visualized osseous structures demonstrates no suspicious - appearing lesions . IMPRESSION : 1 . NO EVIDENCE OF PULMONARY EMBOLISM . SUMMARY : 2 - ABNORMAL , PREVIOUSLY REPORTED I have personally reviewed the images for this examination and agreed with the report transcribed above .
# Parsed Output: [{'general_finding': 'pulmonary embolus', 'specific_finding': 'filling defects', 'finding_presence': 'absent', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'surgical clips', 'specific_finding': 'surgical clips', 'finding_presence': 'present', 'location': ['thyroid bed'], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'thymic tissue', 'specific_finding': 'residual thymic tissue', 'finding_presence': 'present', 'location': ['prevascular space'], 'degree': ['small', 'flat', 'non-confluent', 'fibrofatty'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'heart', 'specific_finding': 'heart size', 'finding_presence': 'present', 'location': [], 'degree': ['normal'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'pericardial effusion', 'specific_finding': 'pericardial effusion', 'finding_presence': 'absent', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'lymphadenopathy', 'specific_finding': 'axillary lymphadenopathy', 'finding_presence': 'absent', 'location': ['axilla'], 'degree': ['significant'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'lymphadenopathy', 'specific_finding': 'mediastinal lymphadenopathy', 'finding_presence': 'absent', 'location': ['mediastinum'], 'degree': ['significant'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'lymphadenopathy', 'specific_finding': 'hilar lymphadenopathy', 'finding_presence': 'absent', 'location': ['hilum'], 'degree': ['significant'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'pulmonary nodules', 'specific_finding': 'nodule', 'finding_presence': 'present', 'location': ['left lower lobe'], 'degree': ['4 mm'], 'measurement': '4 mm', 'comparison': 'stable'}, {'general_finding': 'lung parenchyma', 'specific_finding': 'lung opacities', 'finding_presence': 'absent', 'location': [], 'degree': ['focal'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'pleural effusion', 'specific_finding': 'pleural effusion', 'finding_presence': 'absent', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'upper abdomen', 'specific_finding': 'upper abdominal structures', 'finding_presence': 'present', 'location': [], 'degree': ['unremarkable'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'bone', 'specific_finding': 'osseous structures', 'finding_presence': 'present', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}]
# Processing Samples:  44%|████▍     | 8/18 [04:27<05:02, 30.27s/it]
# ...
# Processing Samples:  89%|████████▉ | 16/18 [09:23<01:21, 40.79s/it]
# Report: EXAM : CT Pulmonary Embolism Chest Only DATE : 8 - 4 - 2019 5 : 32 PM CLINICAL HISTORY : Hypoxia , dyspnea on exertion in a patient with chest pain and hypotension . COMPARISON : Chest x - ray from earlier same day august 04th CONTRAST : 115 cc of Isovue - 300 TECHNIQUE : Following uneventful administration of iodinated intravenous contrast media , multidetector helical CT data acquisition was performed through the thorax during pulmonary arterial phase of contrast . Multiplanar reformatted , 3 - D volume rendered , and maximum intensity projection images were reviewed on an independent workstation . Based on a 32 cm body phantom , the estimated radiation dose ( CTDIvol mGy ) for each series in this exam are : 22 . 5 , 28 . 9 mGy . The estimated cumulative dose ( DLP mGy - cm ) is : 853 . 9 mGy - cm . NOTE : The radiation dose indicators for CT -- the ' volume CT Dose Index ' ( CTDIvol ) given in milli - Gray ( mGy ), and the Dose Length Product ( DLP ) given in mGy - centimeters ( mGy . cm ) -- are generated from the CT scanner to estimate radiation exposure based on technical study parameters and a reference phantom . The CTDI and DLP may therefore substantially over - or underestimate an individual ' s absorbed dose based on patient size and other factors . FINDINGS : There is no evidence for a pulmonary arterial filling defect to suggest pulmonary embolism . The heart is normal in size . There is no pericardial effusion . No adenopathy is seen in the mediastinum , hila , or axilla . The thyroid gland appears enlarged but no discrete thyroid nodule is seen . There is diffuse severe bilateral centrilobular emphysema . Mild atelectasis is present in the lingula . Mild bibasilar subsegmental atelectasis is also noted . There is no lung consolidation . There is no pleural effusion or pneumothorax . Biapical scarring is noted . There is mild bronchial wall thickening , which is nonspecific and may be chronic . Small metallic foreign bodies in the left chest wall , suggestive of bullet fragments . There are moderate degenerative changes in the thoracic spine . No acute osseous abnormality is seen . There is partial visualization of small presumed cyst in the right kidney measuring up to 2 . 2 cm ( series 3 , image one ) . There is an ill - defined rounded area of hyperattenuation in the superior pole of the left kidney , incompletely visualized ( series 3 , image 6 ) . IMPRESSION : 1 . NO EVIDENCE FOR PULMONARY EMBOLISM OR OTHER ACUTE PROCESS IN THE CHEST . 2 . SEVERE CENTRILOBULAR EMPHYSEMA . 3 . PARTIAL VISUALIZATION OF A SUBTLE , ROUNDED HYPERDENSE VERSUS HYPERENHANCING LESION IN THE LEFT RENAL UPPER POLE . RECOMMEND CORRELATION WITH RENAL ULTRASOUND . 4 . THYROMEGALY . THIS CAN ALSO BE FURTHER ASSESSED WITH ULTRASOUND IF CLINICALLY WARRANTED . SUMMARY : 4 - POSSIBLY SIGNIFICANT FINDING , MAY NEED ACTION I have personally reviewed the images for this examination and agreed with the report transcribed above .
# Parsed Output: [{'general_finding': 'pulmonary embolus', 'specific_finding': 'pulmonary embolism', 'finding_presence': 'absent', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'heart', 'specific_finding': 'heart size', 'finding_presence': 'present', 'location': [], 'degree': ['normal'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'pericardial effusion', 'specific_finding': 'pericardial effusion', 'finding_presence': 'absent', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'lymphadenopathy', 'specific_finding': 'lymphadenopathy', 'finding_presence': 'absent', 'location': ['mediastinum', 'hila', 'axilla'], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'thyroid gland', 'specific_finding': 'thyroid enlargement', 'finding_presence': 'present', 'location': [], 'degree': ['enlarged'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'thyroid nodules', 'specific_finding': 'thyroid nodule', 'finding_presence': 'absent', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'emphysema', 'specific_finding': 'centrilobular emphysema', 'finding_presence': 'present', 'location': [], 'degree': ['diffuse', 'severe', 'bilateral'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'atelectasis', 'specific_finding': 'atelectasis', 'finding_presence': 'present', 'location': ['lingula'], 'degree': ['mild'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'atelectasis', 'specific_finding': 'subsegmental atelectasis', 'finding_presence': 'present', 'location': ['bilateral bases'], 'degree': ['mild', 'bibasilar'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'consolidation', 'specific_finding': 'lung consolidation', 'finding_presence': 'absent', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'pleural effusion', 'specific_finding': 'pleural effusion', 'finding_presence': 'absent', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'pneumothorax', 'specific_finding': 'pneumothorax', 'finding_presence': 'absent', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'scarring', 'specific_finding': 'biapical scarring', 'finding_presence': 'present', 'location': ['bilateral apices'], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'airways', 'specific_finding': 'bronchial wall thickening', 'finding_presence': 'present', 'location': [], 'degree': ['mild', 'nonspecific'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'bone', 'specific_finding': 'bullet fragments', 'finding_presence': 'present', 'location': ['left chest wall'], 'degree': ['small', 'metallic'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'spine', 'specific_finding': 'degenerative changes', 'finding_presence': 'present', 'location': ['thoracic spine'], 'degree': ['moderate'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'bone', 'specific_finding': 'osseous abnormality', 'finding_presence': 'absent', 'location': [], 'degree': ['acute'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'kidney', 'specific_finding': 'cyst', 'finding_presence': 'present', 'location': ['right kidney'], 'degree': ['small', 'presumed'], 'measurement': 'up to 2.2 cm', 'comparison': 'None'}, {'general_finding': 'kidney', 'specific_finding': 'hyperattenuation', 'finding_presence': 'uncertain', 'location': ['left kidney'], 'degree': ['ill-defined', 'rounded'], 'measurement': 'None', 'comparison': 'None'}]
# Processing Samples:  94%|█████████▍| 17/18 [09:53<00:37, 37.48s/it]
# Report: EXAM : CT Angio Thorax , 1 - 12 - 17 9 : 24 AM HISTORY : 25 years Male presents to the emergency department after a motor vehicle collision . COMPARISON : Chest radiograph 1 - 12 - 17 TECHNIQUE : After the uneventful administration of intravenous contrast , multiple contiguous axial CT images were acquired through the chest during the arterial phase after contrast administration . Coronal and sagittal reformatted images , as well as maximum intensity images were provided . CONTRAST : Omnipaque 350 , 120 mL . DOSE : Based on a 32 cm body phantom , the estimated radiation dose ( CTDIvol mGy ) for each series in this exam are : 32 . 83 , 16 . 83 , 18 . 19 , 8 . 93 mGy . The estimated cumulative dose ( DLP mGy - cm ) is : 1806 mGy - cm . NOTE : The radiation dose indicators for CT -- the ' volume CT Dose Index ' ( CTDIvol ) given in milli - Gray ( mGy ), and the Dose Length Product ( DLP ) given in mGy - centimeters ( mGy . cm ) -- are generated from the CT scanner to estimate radiation exposure based on technical study parameters and a reference phantom . The CTDI and DLP may therefore substantially over - or underestimate an individual ' s absorbed dose based on patient size and other factors . FINDINGS : LUNGS : No evidence of acute lung injury . No evidence of pleural effusion or pneumothorax . MEDIASTINUM : The thoracic aorta is normal in contour and caliber . No evidence of aortic dissection or pseudoaneurysm . No mediastinal hematoma . UPPER ABDOMEN : Limited evaluation of the upper abdomen is unremarkable with the exception of variant celiac anatomy ( see below ) . BONES : There is a minimally displaced cortical defect of the right 5th rib anterolaterally ( series 3 , image 212 ) . The alignment of the spine is normal . VASCULATURE : No evidence of acute vascular injury . Incidental notation of a bovine arch with the left common carotid artery originating from the innominate artery . There is also variant celiac and hepatic artery anatomy with the common hepatic artery originating from the aorta . Addendum Begins 3D reformations consisting of curved and multiplanar reformations , maximum intensity projections , and volume rendered images were performed on an independent workstation and corroborate the findings . Addendum Ends IMPRESSION : 1 . NO EVIDENCE OF ACUTE VASCULAR INJURY , MEDIASTINAL HEMATOMA , OR PNEUMOTHORAX . 2 . MINIMALLY DISPLACED FRACTURE OF THE RIGHT 5TH RIB ANTEROLATERALLY . 3 . PLEASE REFER TO SEPARATELY DICTATED REPORTS FOR THE SAME DAY CT ' S OF THE ABDOMEN , PELVIS , AND SPINE . PRELIMINARY FINDINGS WERE DISCUSSED WITH Holder Landen MD ( TRAUMA TEAM ) AT 0945 HOURS ON 2017 , January 12 . SUMMARY CODE : SUMMARY : 4 - POSSIBLE SIGNIFICANT FINDING , MAY NEED ACTION . I have personally reviewed the images for this examination and agreed with the report transcribed above .
# Parsed Output: [{'general_finding': 'lung parenchyma', 'specific_finding': 'acute lung injury', 'finding_presence': 'absent', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'pleural effusion', 'specific_finding': 'pleural effusion', 'finding_presence': 'absent', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'pneumothorax', 'specific_finding': 'pneumothorax', 'finding_presence': 'absent', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'thoracic aorta', 'specific_finding': 'aorta contour and caliber', 'finding_presence': 'present', 'location': [], 'degree': ['normal'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'aortic dissection', 'specific_finding': 'aortic dissection', 'finding_presence': 'absent', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'pseudoaneurysm', 'specific_finding': 'pseudoaneurysm', 'finding_presence': 'absent', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'mediastinal hematoma', 'specific_finding': 'mediastinal hematoma', 'finding_presence': 'absent', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'upper abdomen', 'specific_finding': 'upper abdomen', 'finding_presence': 'present', 'location': [], 'degree': ['unremarkable'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'celiac anatomy', 'specific_finding': 'variant celiac anatomy', 'finding_presence': 'present', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'bone', 'specific_finding': 'cortical defect', 'finding_presence': 'present', 'location': ['right 5th rib anterolaterally'], 'degree': ['minimally displaced'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'spine', 'specific_finding': 'spine alignment', 'finding_presence': 'present', 'location': [], 'degree': ['normal'], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'vascular injury', 'specific_finding': 'acute vascular injury', 'finding_presence': 'absent', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'aorta', 'specific_finding': 'bovine arch', 'finding_presence': 'present', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'common carotid artery', 'specific_finding': 'left common carotid artery origin', 'finding_presence': 'present', 'location': ['left common carotid artery'], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'innominate artery', 'specific_finding': 'left common carotid artery origin', 'finding_presence': 'present', 'location': ['innominate artery'], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'celiac artery', 'specific_finding': 'variant celiac artery anatomy', 'finding_presence': 'present', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'hepatic artery', 'specific_finding': 'variant hepatic artery anatomy', 'finding_presence': 'present', 'location': [], 'degree': [], 'measurement': 'None', 'comparison': 'None'}, {'general_finding': 'common hepatic artery', 'specific_finding': 'common hepatic artery origin', 'finding_presence': 'present', 'location': ['aorta'], 'degree': [], 'measurement': 'None', 'comparison': 'None'}]
# Processing Samples: 100%|██████████| 18/18 [10:26<00:00, 34.81s/it]

# %% [markdown]
# ## Saving as Pretty JSON

# %%
import json

INPUT_PATH = "/kaggle/working/chest-ct-schema-random20.json"
OUTPUT_PATH = "/kaggle/working/chest-ct-schema.pretty-random20.jsonl"

with open(INPUT_PATH, "r", encoding="utf-8") as fin, open(OUTPUT_PATH, "w", encoding="utf-8") as fout:
    for line in fin:
        line = line.strip()
        if not line:
            continue

        obj = json.loads(line)

        # her kaydı indent'li yaz
        fout.write(json.dumps(obj, ensure_ascii=False, indent=2))
        fout.write("\n\n")  # kayıtlar arası boşluk

print("Saved ->", OUTPUT_PATH)
# Out:
# Saved -> /kaggle/working/chest-ct-schema.pretty-random20.jsonl

# %%
# INPUT_PATH = "/kaggle/input/radgraph/stanford-radgraph-XL-sentence.jsonl"
# OUTPUT_PATH = "/kaggle/working/stanford-radgraph-XL-mapped.jsonl"

# dataset = load_jsonl(INPUT_PATH)[1:]

# results = run_inference_radgraph(
#     dataset=dataset,
#     output_path=OUTPUT_PATH,
#     model_id="deepseek",
#     model_name="deepseek-chat",
# )
